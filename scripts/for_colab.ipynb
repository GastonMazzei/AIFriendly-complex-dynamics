# %% [markdown]
# <h2>instructions: <br><b>Press "runn all" and go to the bottom to connect to GoogleDrive</b></h2>

# %% [markdown]
# <b> (1) Functions used to generate two-dimensional second-order ordinary differential equations and calculate their fixed points </b>
# <br><i>(slowest part of the code!)</i>

# %%
import sys
import pickle

import numpy as np
from sympy.solvers import nonlinsolve, solve, solveset

from sympy.geometry import Point
from sympy.core.symbol import symbols
from sympy import Symbol, Eq

def find_zeros(p: list):

  #*** this is the equation!
  #              0,5       1,6       2,7         3,8        4,9
  # d(x) = dt * (a_1 * x + b_1 * y + c_1 * x^2 + d_1 * x*y + e_1 * y^2) 
  # d(y) = dt * (a_2 * x + b_2 * y + c_2 * x^2 + d_2 * y*x + e_2 * y^2) 

  x, y = symbols('x y')
  Z = Point(x,y)
  r = solve([
             Z[0] * p[0] + Z[1] * p[1] + (Z[0]**2) * p[2] + (Z[0]**2) * p[4] + (Z[0]*Z[1]) * p[3],
             Z[0] * p[5] + Z[1] * p[6] + (Z[0]**2) * p[7] + (Z[1]**2) * p[9] + (Z[0]*Z[1]) * p[8],
                  ],Z,real=True)
  output = []
  for x in r:
    if x[0].is_real and x[1].is_real: output.append(x)
  if len(output)==1: output.append(output[0])
  return tuple(output)

def eval(p: list, Z: list):
  """
  auxiliary function for testing the roots that "find_zeros" finds!
  """
  return  (Z[0] * p[0] + Z[1] * p[1] + (Z[0]**2) * p[2] + (Z[0]**2) * p[4] + (Z[0]*Z[1]) * p[3],
             Z[0] * p[5] + Z[1] * p[6] + (Z[0]**2) * p[7] + (Z[1]**2) * p[9] + (Z[0]*Z[1]) * p[8])

def view(i):
  """
  auxiliary function for testing the roots that "find_zeros" finds!
  """
  try:
    with open('equations_and_solutions.pkl','rb') as w: data=pickle.load(w)
  except:
    with open('database/equations_and_solutions.pkl','rb') as w: data=pickle.load(w)
  k = list(data.keys())
  for j in range(len(data[k[i]])):
    print(f'root N {j} is {data[k[i]][j]} and evals to {eval(k[i],data[k[i]][j])}')


def generate_parameters(size: int = 10):
  return tuple(np.random.rand()*np.random.choice([-1,1],size))


def generator(TIMES):
  from datetime import datetime
  from dateutil.relativedelta import relativedelta
  data = {}
  ta = datetime.now()
  for _ in range(TIMES):
    if _%20==0: 
      tb = datetime.now()
      dt = relativedelta(tb,ta)
      print(f'Lap {_} of {TIMES} took {dt.seconds+dt.microseconds/1e6} seconds\n')
      ta = datetime.now()
    p = generate_parameters()
    z = find_zeros(p)
    data[tuple(p)] = z
  return data

# %% [markdown]
# <b> (2) Functions used to calculate the stability of the fixed points and make a veredict about the equation </b>
# <br><i>(i.e. answer the question: does it have unstable equilibriums and hence do regions forbidden at infinite time exist?)</i>

# %%
#!/usr/bin/env python

import numpy as np
import pandas as pd
import pickle

def matrix_calculator(p, x):
  """ 
  only for order 2!
  """
  #              0,5       1,6       2,7         3,8        4,9
  # d(x) = dt * (a_1 * x + b_1 * y + c_1 * x^2 + d_1 * x*y + e_1 * y^2) 
  # d(y) = dt * (a_2 * x + b_2 * y + c_2 * x^2 + d_2 * y*x + e_2 * y^2) 
  return    np.asarray([
              [  p[0]+2*p[2]*x[0]+p[3]*x[1],
                 p[1]+2*p[4]*x[1]+p[3]*x[0],],

              [  p[5]+2*p[7]*x[0]+p[8]*x[1],
                 p[6]+2*p[9]*x[1]+p[8]*x[0],],
                             ], dtype=np.float32)
                

def convergence_veredict(matrix):
  eigs = np.linalg.eigvals(matrix)
  realparts = []
  for x in eigs:
    if np.isreal(x): realparts.append(x)
    else: realparts.append(x.real)
  if max(realparts)>0: return 1
  else: return 0

def rule(p,x):
  return convergence_veredict(matrix_calculator(p,x))

# %% [markdown]
# <b>(3) connect to Google Drive and generate the database that our network will fit!</b>

# %%
if True:

  # (0) connect to Google Drive
  from google.colab import drive
  drive.mount('/content/drive')
  import os
  try:
    os.mkdir('drive/My Drive/complex-dynamics')
  except: pass

  # (1) initialize
  data = {}
  names = [
           #'x0','y0',
              'a_1','b_1','c_1','d_1','e_1',
              'a_2','b_2','c_2','d_2','e_2',
                                       'divergence',]
  for x in names: data[x] = []

  # (2) generate equations and calculate their stationary points
  TIMES = 20000
  print(f'about to generate {TIMES} equations... will take approximately {TIMES//2} seconds')
  equations_and_solutions = generator(TIMES)

  # (3) append the convergence veredict for every case
  for k in equations_and_solutions.keys():
    counter = 0
    for j in equations_and_solutions[k]:        
      counter += rule(k, j)
    if counter>0: counter=1
    param = k + (float(counter),)
    for i,x in enumerate(names): data[x] += [param[i]]

  # (4) balance dataset
  df = pd.DataFrame(data)
  q = df['divergence'].value_counts()
  m = np.argmin([q[i] for i in range(2)])
  df = pd.concat([df[df['divergence']==m], df[~(df['divergence']==m)][:int(q[m]*1.25)]],0).sample(frac=1)

  # (5) save
  df.to_csv('drive/My Drive/complex-dynamics/database.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# about to generate 20000 equations... will take approximately 10000 seconds
# Lap 0 of 20000 took 1.4e-05 seconds
#
# Lap 20 of 20000 took 25.592191 seconds
#
# Lap 40 of 20000 took 15.289072 seconds
#
# Lap 60 of 20000 took 20.973554 seconds
#
# Lap 80 of 20000 took 19.492843 seconds
#
# Lap 100 of 20000 took 24.961262 seconds
#
# Lap 120 of 20000 took 25.480743 seconds
#
# Lap 140 of 20000 took 28.166061 seconds
#
# Lap 160 of 20000 took 21.929697 seconds
#
# Lap 180 of 20000 took 24.297552 seconds
#
# Lap 200 of 20000 took 25.161191 seconds
#
# Lap 220 of 20000 took 25.771116 seconds
#
# Lap 240 of 20000 took 21.41745 seconds
#
# Lap 260 of 20000 took 17.837261 seconds
#
# Lap 280 of 20000 took 15.633012 seconds
#
# Lap 300 of 20000 took 12.787443 seconds
#
# Lap 320 of 20000 took 25.594576 seconds
#
# Lap 340 of 20000 took 25.673089 seconds
#
# Lap 360 of 20000 took 16.098479 seconds
#
# Lap 380 of 20000 took 20.397368 seconds
#
# Lap 400 of 20000 took 13.209079 seconds
#
# Lap 420 of 20000 took 21.231307 seconds
#
# Lap 440 of 20000 took 16.516644 seconds
#
# Lap 460 of 20000 took 15.557604 seconds
#
# Lap 480 of 20000 took 22.232535 seconds
#
# Lap 500 of 20000 took 23.219367 seconds
#
# Lap 520 of 20000 took 21.160009 seconds
#
# Lap 540 of 20000 took 21.374538 seconds
#
# Lap 560 of 20000 took 21.690284 seconds
#
# Lap 580 of 20000 took 21.188159 seconds
#
# Lap 600 of 20000 took 12.928559 seconds
#
# Lap 620 of 20000 took 15.923982 seconds
#
# Lap 640 of 20000 took 32.079912 seconds
#
# Lap 660 of 20000 took 20.895778 seconds
#
# Lap 680 of 20000 took 26.388141 seconds
#
# Lap 700 of 20000 took 23.712156 seconds
#
# Lap 720 of 20000 took 20.249427 seconds
#
# Lap 740 of 20000 took 18.962867 seconds
#
# Lap 760 of 20000 took 21.532817 seconds
#
# Lap 780 of 20000 took 21.047767 seconds
#
# Lap 800 of 20000 took 24.092542 seconds
#
# Lap 820 of 20000 took 20.444808 seconds
#
# Lap 840 of 20000 took 17.892906 seconds
#
# Lap 860 of 20000 took 22.13385 seconds
#
# Lap 880 of 20000 took 18.688347 seconds
#
# Lap 900 of 20000 took 25.99819 seconds
#
# Lap 920 of 20000 took 18.976122 seconds
#
# Lap 940 of 20000 took 21.74126 seconds
#
# Lap 960 of 20000 took 20.666618 seconds
#
# Lap 980 of 20000 took 16.427519 seconds
#
# Lap 1000 of 20000 took 22.410982 seconds
#
# Lap 1020 of 20000 took 16.69036 seconds
#
# Lap 1040 of 20000 took 22.419321 seconds
#
# Lap 1060 of 20000 took 19.72714 seconds
#
# Lap 1080 of 20000 took 19.57921 seconds
#
# Lap 1100 of 20000 took 20.07754 seconds
#
# Lap 1120 of 20000 took 23.867125 seconds
#
# Lap 1140 of 20000 took 22.580609 seconds
#
# Lap 1160 of 20000 took 21.377826 seconds
#
# Lap 1180 of 20000 took 21.103174 seconds
#
# Lap 1200 of 20000 took 17.074509 seconds
#
# Lap 1220 of 20000 took 22.367861 seconds
#
# Lap 1240 of 20000 took 14.847332 seconds
#
# Lap 1260 of 20000 took 19.846661 seconds
#
# Lap 1280 of 20000 took 23.514396 seconds
#
# Lap 1300 of 20000 took 12.536305 seconds
#
# Lap 1320 of 20000 took 16.766111 seconds
#
# Lap 1340 of 20000 took 19.039356 seconds
#
# Lap 1360 of 20000 took 16.554428 seconds
#
# Lap 1380 of 20000 took 25.161842 seconds
#
# Lap 1400 of 20000 took 18.060022 seconds
#
# Lap 1420 of 20000 took 17.66304 seconds
#
# Lap 1440 of 20000 took 21.711942 seconds
#
# Lap 1460 of 20000 took 16.71604 seconds
#
# Lap 1480 of 20000 took 19.292288 seconds
#
# Lap 1500 of 20000 took 18.635267 seconds
#
# Lap 1520 of 20000 took 17.793477 seconds
#
# Lap 1540 of 20000 took 20.640543 seconds
#
# Lap 1560 of 20000 took 22.929215 seconds
#
# Lap 1580 of 20000 took 21.03546 seconds
#
# Lap 1600 of 20000 took 18.616903 seconds
#
# Lap 1620 of 20000 took 19.744206 seconds
#
# Lap 1640 of 20000 took 20.422325999999998 seconds
#
# Lap 1660 of 20000 took 18.940355 seconds
#
# Lap 1680 of 20000 took 14.806929 seconds
#
# Lap 1700 of 20000 took 20.510248 seconds
#
# Lap 1720 of 20000 took 20.107488 seconds
#
# Lap 1740 of 20000 took 21.826058 seconds
#
# Lap 1760 of 20000 took 16.849761 seconds
#
# Lap 1780 of 20000 took 24.062026 seconds
#
# Lap 1800 of 20000 took 25.229982 seconds
#
# Lap 1820 of 20000 took 17.849784 seconds
#
# Lap 1840 of 20000 took 18.860719 seconds
#
# Lap 1860 of 20000 took 22.947366 seconds
#
# Lap 1880 of 20000 took 13.689275 seconds
#
# Lap 1900 of 20000 took 15.552993 seconds
#
# Lap 1920 of 20000 took 19.756432 seconds
#
# Lap 1940 of 20000 took 17.354766 seconds
#
# Lap 1960 of 20000 took 15.259005 seconds
#
# Lap 1980 of 20000 took 25.309352 seconds
#
# Lap 2000 of 20000 took 16.535973 seconds
#
# Lap 2020 of 20000 took 19.886098 seconds
#
# Lap 2040 of 20000 took 23.687344 seconds
#
# Lap 2060 of 20000 took 16.460162 seconds
#
# Lap 2080 of 20000 took 18.761779 seconds
#
# Lap 2100 of 20000 took 19.676913 seconds
#
# Lap 2120 of 20000 took 24.237169 seconds
#
# Lap 2140 of 20000 took 24.481456 seconds
#
# Lap 2160 of 20000 took 25.955083 seconds
#
# Lap 2180 of 20000 took 20.180612 seconds
#
# Lap 2200 of 20000 took 23.094861 seconds
#
# Lap 2220 of 20000 took 15.688967 seconds
#
# Lap 2240 of 20000 took 24.634797 seconds
#
# Lap 2260 of 20000 took 20.877035 seconds
#
# Lap 2280 of 20000 took 19.171839 seconds
#
# Lap 2300 of 20000 took 16.060263 seconds
#
# Lap 2320 of 20000 took 26.693608 seconds
#
# Lap 2340 of 20000 took 17.293622 seconds
#
# Lap 2360 of 20000 took 19.097343 seconds
#
# Lap 2380 of 20000 took 18.58973 seconds
#
# Lap 2400 of 20000 took 14.819793 seconds
#
# Lap 2420 of 20000 took 20.90137 seconds
#
# Lap 2440 of 20000 took 25.221545 seconds
#
# Lap 2460 of 20000 took 12.156563 seconds
#
# Lap 2480 of 20000 took 23.828362 seconds
#
# Lap 2500 of 20000 took 20.93551 seconds
#
# Lap 2520 of 20000 took 19.823444 seconds
#
# Lap 2540 of 20000 took 18.269672 seconds
#
# Lap 2560 of 20000 took 24.662441 seconds
#
# Lap 2580 of 20000 took 19.059632 seconds
#
# Lap 2600 of 20000 took 17.997862 seconds
#
# Lap 2620 of 20000 took 23.153534 seconds
#
# Lap 2640 of 20000 took 13.741275 seconds
#
# Lap 2660 of 20000 took 13.222322 seconds
#
# Lap 2680 of 20000 took 23.811077 seconds
#
# Lap 2700 of 20000 took 22.84103 seconds
#
# Lap 2720 of 20000 took 16.81299 seconds
#
# Lap 2740 of 20000 took 22.873429 seconds
#
# Lap 2760 of 20000 took 18.396647 seconds
#
# Lap 2780 of 20000 took 10.375946 seconds
#
# Lap 2800 of 20000 took 26.141636 seconds
#
# Lap 2820 of 20000 took 19.609018 seconds
#
# Lap 2840 of 20000 took 27.50312 seconds
#
# Lap 2860 of 20000 took 17.660236 seconds
#
# Lap 2880 of 20000 took 17.845248 seconds
#
# Lap 2900 of 20000 took 19.019931 seconds
#
# Lap 2920 of 20000 took 20.396204 seconds
#
# Lap 2940 of 20000 took 17.754731 seconds
#
# Lap 2960 of 20000 took 22.111279 seconds
#
# Lap 2980 of 20000 took 22.997088 seconds
#
# Lap 3000 of 20000 took 24.325618 seconds
#
# Lap 3020 of 20000 took 20.121339 seconds
#
# Lap 3040 of 20000 took 16.002493 seconds
#
# Lap 3060 of 20000 took 22.536312 seconds
#
# Lap 3080 of 20000 took 15.112939 seconds
#
# Lap 3100 of 20000 took 21.76197 seconds
#
# Lap 3120 of 20000 took 23.588188 seconds
#
# Lap 3140 of 20000 took 12.429178 seconds
#
# Lap 3160 of 20000 took 18.492473 seconds
#
# Lap 3180 of 20000 took 18.649881 seconds
#
# Lap 3200 of 20000 took 23.124821 seconds
#
# Lap 3220 of 20000 took 21.184267 seconds
#
# Lap 3240 of 20000 took 19.276534 seconds
#
# Lap 3260 of 20000 took 20.750876 seconds
#
# Lap 3280 of 20000 took 17.211946 seconds
#
# Lap 3300 of 20000 took 24.296406 seconds
#
# Lap 3320 of 20000 took 25.425374 seconds
#
# Lap 3340 of 20000 took 20.390748 seconds
#
# Lap 3360 of 20000 took 19.631393 seconds
#
# Lap 3380 of 20000 took 22.3179 seconds
#
# Lap 3400 of 20000 took 18.084578 seconds
#
# Lap 3420 of 20000 took 20.313786 seconds
#
# Lap 3440 of 20000 took 16.623465 seconds
#
# Lap 3460 of 20000 took 28.427584 seconds
#
# Lap 3480 of 20000 took 21.133743 seconds
#
# Lap 3500 of 20000 took 17.576178 seconds
#
# Lap 3520 of 20000 took 18.258867 seconds
#
# Lap 3540 of 20000 took 18.451143 seconds
#
# Lap 3560 of 20000 took 18.297455 seconds
#
# Lap 3580 of 20000 took 18.558041 seconds
#
# Lap 3600 of 20000 took 15.629775 seconds
#
# Lap 3620 of 20000 took 23.362681 seconds
#
# Lap 3640 of 20000 took 21.412903 seconds
#
# Lap 3660 of 20000 took 19.451681 seconds
#
# Lap 3680 of 20000 took 11.277957 seconds
#
# Lap 3700 of 20000 took 19.257232 seconds
#
# Lap 3720 of 20000 took 20.823743 seconds
#
# Lap 3740 of 20000 took 22.520133 seconds
#
# Lap 3760 of 20000 took 25.144223 seconds
#
# Lap 3780 of 20000 took 15.59919 seconds
#
# Lap 3800 of 20000 took 21.886056 seconds
#
# Lap 3820 of 20000 took 14.580399 seconds
#
# Lap 3840 of 20000 took 20.090519 seconds
#
# Lap 3860 of 20000 took 21.748108 seconds
#
# Lap 3880 of 20000 took 17.352192 seconds
#
# Lap 3900 of 20000 took 19.841505 seconds
#
# Lap 3920 of 20000 took 20.775872 seconds
#
# Lap 3940 of 20000 took 27.018215 seconds
#
# Lap 3960 of 20000 took 15.980925 seconds
#
# Lap 3980 of 20000 took 23.774829 seconds
#
# Lap 4000 of 20000 took 18.870505 seconds
#
# Lap 4020 of 20000 took 21.824981 seconds
#
# Lap 4040 of 20000 took 14.423599 seconds
#
# Lap 4060 of 20000 took 19.580163 seconds
#
# Lap 4080 of 20000 took 20.784448 seconds
#
# Lap 4100 of 20000 took 23.604979 seconds
#
# Lap 4120 of 20000 took 19.361747 seconds
#
# Lap 4140 of 20000 took 27.513935 seconds
#
# Lap 4160 of 20000 took 24.778124 seconds
#
# Lap 4180 of 20000 took 19.498757 seconds
#
# Lap 4200 of 20000 took 19.112951 seconds
#
# Lap 4220 of 20000 took 29.094505 seconds
#
# Lap 4240 of 20000 took 19.8198 seconds
#
# Lap 4260 of 20000 took 17.897299 seconds
#
# Lap 4280 of 20000 took 17.577078 seconds
#
# Lap 4300 of 20000 took 17.803877 seconds
#
# Lap 4320 of 20000 took 24.647531 seconds
#
# Lap 4340 of 20000 took 20.587598 seconds
#
# Lap 4360 of 20000 took 16.810199 seconds
#
# Lap 4380 of 20000 took 27.16721 seconds
#
# Lap 4400 of 20000 took 12.868932000000001 seconds
#
# Lap 4420 of 20000 took 22.246439 seconds
#
# Lap 4440 of 20000 took 26.769608 seconds
#
# Lap 4460 of 20000 took 20.764243 seconds
#
# Lap 4480 of 20000 took 24.281608 seconds
#
# Lap 4500 of 20000 took 25.271398 seconds
#
# Lap 4520 of 20000 took 18.382869 seconds
#
# Lap 4540 of 20000 took 22.896522 seconds
#
# Lap 4560 of 20000 took 21.022553 seconds
#
# Lap 4580 of 20000 took 24.775375 seconds
#
# Lap 4600 of 20000 took 17.344272 seconds
#
# Lap 4620 of 20000 took 20.282875 seconds
#
# Lap 4640 of 20000 took 27.138709 seconds
#
# Lap 4660 of 20000 took 22.859966 seconds
#
# Lap 4680 of 20000 took 22.294646 seconds
#
# Lap 4700 of 20000 took 20.232302 seconds
#
# Lap 4720 of 20000 took 17.200218 seconds
#
# Lap 4740 of 20000 took 22.735263 seconds
#
# Lap 4760 of 20000 took 18.556033 seconds
#
# Lap 4780 of 20000 took 17.751384 seconds
#
# Lap 4800 of 20000 took 17.302977 seconds
#
# Lap 4820 of 20000 took 22.97586 seconds
#
# Lap 4840 of 20000 took 21.308267 seconds
#
# Lap 4860 of 20000 took 23.986506 seconds
#
# Lap 4880 of 20000 took 19.699125 seconds
#
# Lap 4900 of 20000 took 23.66738 seconds
#
# Lap 4920 of 20000 took 20.49416 seconds
#
# Lap 4940 of 20000 took 21.27928 seconds
#
# Lap 4960 of 20000 took 29.092725 seconds
#
# Lap 4980 of 20000 took 20.50265 seconds
#
# Lap 5000 of 20000 took 18.409993 seconds
#
# Lap 5020 of 20000 took 17.754383 seconds
#
# Lap 5040 of 20000 took 24.342354 seconds
#
# Lap 5060 of 20000 took 24.44527 seconds
#
# Lap 5080 of 20000 took 19.252902 seconds
#
# Lap 5100 of 20000 took 23.643287 seconds
#
# Lap 5120 of 20000 took 23.76456 seconds
#
# Lap 5140 of 20000 took 19.813222 seconds
#
# Lap 5160 of 20000 took 22.442768 seconds
#
# Lap 5180 of 20000 took 22.320084 seconds
#
# Lap 5200 of 20000 took 19.479023 seconds
#
# Lap 5220 of 20000 took 18.362559 seconds
#
# Lap 5240 of 20000 took 17.096294 seconds
#
# Lap 5260 of 20000 took 22.352681 seconds
#
# Lap 5280 of 20000 took 9.584232 seconds
#
# Lap 5300 of 20000 took 19.410852 seconds
#
# Lap 5320 of 20000 took 23.009119 seconds
#
# Lap 5340 of 20000 took 20.490315 seconds
#
# Lap 5360 of 20000 took 17.933319 seconds
#
# Lap 5380 of 20000 took 25.948044 seconds
#
# Lap 5400 of 20000 took 16.994398 seconds
#
# Lap 5420 of 20000 took 20.92688 seconds
#
# Lap 5440 of 20000 took 24.523476 seconds
#
# Lap 5460 of 20000 took 23.98986 seconds
#
# Lap 5480 of 20000 took 18.402185 seconds
#
# Lap 5500 of 20000 took 20.238461 seconds
#
# Lap 5520 of 20000 took 24.439823 seconds
#
# Lap 5540 of 20000 took 21.534812 seconds
#
# Lap 5560 of 20000 took 12.806754 seconds
#
# Lap 5580 of 20000 took 20.189319 seconds
#
# Lap 5600 of 20000 took 14.468881 seconds
#
# Lap 5620 of 20000 took 20.018559 seconds
#
# Lap 5640 of 20000 took 18.348037 seconds
#
# Lap 5660 of 20000 took 24.682107 seconds
#
# Lap 5680 of 20000 took 15.541845 seconds
#
# Lap 5700 of 20000 took 25.441562 seconds
#
# Lap 5720 of 20000 took 22.950964 seconds
#
# Lap 5740 of 20000 took 22.08297 seconds
#
# Lap 5760 of 20000 took 17.012009 seconds
#
# Lap 5780 of 20000 took 16.108314 seconds
#
# Lap 5800 of 20000 took 16.71666 seconds
#
# Lap 5820 of 20000 took 21.690293 seconds
#
# Lap 5840 of 20000 took 23.379719 seconds
#
# Lap 5860 of 20000 took 20.042259 seconds
#
# Lap 5880 of 20000 took 16.203525 seconds
#
# Lap 5900 of 20000 took 23.407271 seconds
#
# Lap 5920 of 20000 took 24.259479 seconds
#
# Lap 5940 of 20000 took 19.235699 seconds
#
# Lap 5960 of 20000 took 21.26161 seconds
#
# Lap 5980 of 20000 took 14.737568 seconds
#
# Lap 6000 of 20000 took 25.875631 seconds
#
# Lap 6020 of 20000 took 18.559505 seconds
#
# Lap 6040 of 20000 took 26.770592 seconds
#
# Lap 6060 of 20000 took 17.066888 seconds
#
# Lap 6080 of 20000 took 22.650662 seconds
#
# Lap 6100 of 20000 took 19.423451 seconds
#
# Lap 6120 of 20000 took 17.652734 seconds
#
# Lap 6140 of 20000 took 26.971367 seconds
#
# Lap 6160 of 20000 took 21.037928 seconds
#
# Lap 6180 of 20000 took 21.550482 seconds
#
# Lap 6200 of 20000 took 22.942667 seconds
#
# Lap 6220 of 20000 took 17.940465 seconds
#
# Lap 6240 of 20000 took 23.876427 seconds
#
# Lap 6260 of 20000 took 17.655281 seconds
#
# Lap 6280 of 20000 took 19.524138 seconds
#
# Lap 6300 of 20000 took 14.446717 seconds
#
# Lap 6320 of 20000 took 26.330852 seconds
#
# Lap 6340 of 20000 took 25.446804 seconds
#
# Lap 6360 of 20000 took 19.682777 seconds
#
# Lap 6380 of 20000 took 21.642066 seconds
#
# Lap 6400 of 20000 took 23.972298 seconds
#
# Lap 6420 of 20000 took 17.813752 seconds
#
# Lap 6440 of 20000 took 18.921219 seconds
#
# Lap 6460 of 20000 took 14.25964 seconds
#
# Lap 6480 of 20000 took 24.875748 seconds
#
# Lap 6500 of 20000 took 18.829703 seconds
#
# Lap 6520 of 20000 took 19.088393 seconds
#
# Lap 6540 of 20000 took 21.289383 seconds
#
# Lap 6560 of 20000 took 19.229383 seconds
#
# Lap 6580 of 20000 took 18.792078 seconds
#
# Lap 6600 of 20000 took 16.055048 seconds
#
# Lap 6620 of 20000 took 21.853174 seconds
#
# Lap 6640 of 20000 took 17.661872 seconds
#
# Lap 6660 of 20000 took 26.341661 seconds
#
# Lap 6680 of 20000 took 23.490307 seconds
#
# Lap 6700 of 20000 took 22.302586 seconds
#
# Lap 6720 of 20000 took 20.173927 seconds
#
# Lap 6740 of 20000 took 16.744953 seconds
#
# Lap 6760 of 20000 took 20.723511 seconds
#
# Lap 6780 of 20000 took 22.18617 seconds
#
# Lap 6800 of 20000 took 23.006411 seconds
#
# Lap 6820 of 20000 took 15.746641 seconds
#
# Lap 6840 of 20000 took 20.27886 seconds
#
# Lap 6860 of 20000 took 16.904749 seconds
#
# Lap 6880 of 20000 took 14.719225 seconds
#
# Lap 6900 of 20000 took 21.438342 seconds
#
# Lap 6920 of 20000 took 19.711677 seconds
#
# Lap 6940 of 20000 took 24.951075 seconds
#
# Lap 6960 of 20000 took 23.549147 seconds
#
# Lap 6980 of 20000 took 20.796954 seconds
#
# Lap 7000 of 20000 took 20.516778 seconds
#
# Lap 7020 of 20000 took 16.645354 seconds
#
# Lap 7040 of 20000 took 22.282783 seconds
#
# Lap 7060 of 20000 took 20.572831 seconds
#
# Lap 7080 of 20000 took 25.878822 seconds
#
# Lap 7100 of 20000 took 17.644341 seconds
#
# Lap 7120 of 20000 took 21.198688 seconds
#
# Lap 7140 of 20000 took 24.946771 seconds
#
# Lap 7160 of 20000 took 17.32761 seconds
#
# Lap 7180 of 20000 took 22.89181 seconds
#
# Lap 7200 of 20000 took 25.19783 seconds
#
# Lap 7220 of 20000 took 15.644409 seconds
#
# Lap 7240 of 20000 took 20.267083 seconds
#
# Lap 7260 of 20000 took 16.450814 seconds
#
# Lap 7280 of 20000 took 21.756966 seconds
#
# Lap 7300 of 20000 took 19.644096 seconds
#
# Lap 7320 of 20000 took 28.449974 seconds
#
# Lap 7340 of 20000 took 15.872534 seconds
#
# Lap 7360 of 20000 took 25.944775 seconds
#
# Lap 7380 of 20000 took 21.981304 seconds
#
# Lap 7400 of 20000 took 18.642356 seconds
#
# Lap 7420 of 20000 took 23.845311 seconds
#
# Lap 7440 of 20000 took 17.444484 seconds
#
# Lap 7460 of 20000 took 19.845722 seconds
#
# Lap 7480 of 20000 took 16.170384 seconds
#
# Lap 7500 of 20000 took 23.745101 seconds
#
# Lap 7520 of 20000 took 18.826894 seconds
#
# Lap 7540 of 20000 took 14.871961 seconds
#
# Lap 7560 of 20000 took 17.989386 seconds
#
# Lap 7580 of 20000 took 24.429529 seconds
#
# Lap 7600 of 20000 took 22.062791 seconds
#
# Lap 7620 of 20000 took 27.212027 seconds
#
# Lap 7640 of 20000 took 21.747333 seconds
#
# Lap 7660 of 20000 took 23.965626 seconds
#
# Lap 7680 of 20000 took 24.762053 seconds
#
# Lap 7700 of 20000 took 16.250392 seconds
#
# Lap 7720 of 20000 took 23.840144 seconds
#
# Lap 7740 of 20000 took 22.83035 seconds
#
# Lap 7760 of 20000 took 20.08322 seconds
#
# Lap 7780 of 20000 took 21.874427 seconds
#
# Lap 7800 of 20000 took 31.812288 seconds
#
# Lap 7820 of 20000 took 20.506276 seconds
#
# Lap 7840 of 20000 took 17.730011 seconds
#
# Lap 7860 of 20000 took 17.116212 seconds
#
# Lap 7880 of 20000 took 20.167927 seconds
#
# Lap 7900 of 20000 took 23.826807 seconds
#
# Lap 7920 of 20000 took 26.928465 seconds
#
# Lap 7940 of 20000 took 13.174465 seconds
#
# Lap 7960 of 20000 took 28.244175 seconds
#
# Lap 7980 of 20000 took 22.73307 seconds
#
# Lap 8000 of 20000 took 26.641294 seconds
#
# Lap 8020 of 20000 took 15.092285 seconds
#
# Lap 8040 of 20000 took 23.918659 seconds
#
# Lap 8060 of 20000 took 17.803058 seconds
#
# Lap 8080 of 20000 took 25.628362 seconds
#
# Lap 8100 of 20000 took 23.920719 seconds
#
# Lap 8120 of 20000 took 23.488065 seconds
#
# Lap 8140 of 20000 took 23.263906 seconds
#
# Lap 8160 of 20000 took 16.032728 seconds
#
# Lap 8180 of 20000 took 21.29006 seconds
#
# Lap 8200 of 20000 took 20.59626 seconds
#
# Lap 8220 of 20000 took 15.507078 seconds
#
# Lap 8240 of 20000 took 22.519832 seconds
#
# Lap 8260 of 20000 took 23.793756 seconds
#
# Lap 8280 of 20000 took 25.197733 seconds
#
# Lap 8300 of 20000 took 20.91445 seconds
#
# Lap 8320 of 20000 took 24.060321 seconds
#
# Lap 8340 of 20000 took 15.89248 seconds
#
# Lap 8360 of 20000 took 21.996498 seconds
#
# Lap 8380 of 20000 took 14.750174 seconds
#
# Lap 8400 of 20000 took 21.185533 seconds
#
# Lap 8420 of 20000 took 24.436142 seconds
#
# Lap 8440 of 20000 took 25.699145 seconds
#
# Lap 8460 of 20000 took 13.36831 seconds
#
# Lap 8480 of 20000 took 22.089293 seconds
#
# Lap 8500 of 20000 took 16.528743 seconds
#
# Lap 8520 of 20000 took 21.26396 seconds
#
# Lap 8540 of 20000 took 17.304583 seconds
#
# Lap 8560 of 20000 took 20.382477 seconds
#
# Lap 8580 of 20000 took 20.149426 seconds
#
# Lap 8600 of 20000 took 23.315142 seconds
#
# Lap 8620 of 20000 took 18.841605 seconds
#
# Lap 8640 of 20000 took 21.885088 seconds
#
# Lap 8660 of 20000 took 20.055242 seconds
#
# Lap 8680 of 20000 took 18.622607 seconds
#
# Lap 8700 of 20000 took 22.404088 seconds
#
# Lap 8720 of 20000 took 20.360616 seconds

# %%
# THIS WILL KEEP COLLAB RUNNING 
# paste it in the browser's console; alternatively keep visiting the script every <30mins
#(max time= 12hs)
jsfunc="""
function ClickConnect(){
  colab.config
  console.log("Connnect Clicked - Start"); 
  document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
  console.log("Connnect Clicked - End");
};
setInterval(ClickConnect, 1000000)
"""
